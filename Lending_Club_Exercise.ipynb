# %% [markdown]
# # Import all necessary libraries which supports this data analysis project
# ## Step 1. Understanding the data by go throughing each columns
# ### Keep the original file as backup and use copy of the file for clean-up if ur doing via excel
# ### refer the Data Dictionary to understand any specific columns if your not sure

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#lending=pd.read_csv(r"C:\Personal\UpGrad\Lending_Club_Excercise\Grade_Excercise\loan\loan.csv")
lending=pd.read_csv(r"C:\Data\loan.csv", low_memory = False)
lending.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %% [markdown]
# ## Try understanding the entire dataset

# %%
lending.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %% [markdown]
# # Post review of the dataset on MS excel, we identified that following columns are not required for data analysis as they do not have data for larger percentile or those values do not seem to help us identify defaulter;
#
# ### Total 87 columns

# %% [markdown]
# ### 'id','member_id','funded_amnt','funded_amnt_inv','emp_title','pymnt_plan','url','desc','title','zip_code','dti','delinq_2yrs','earliest_cr_line','inq_last_6mths','mths_since_last_delinq','mths_since_last_record','open_acc','pub_rec','revol_bal','revol_util','total_acc','initial_list_status','out_prncp','out_prncp_inv','total_pymnt','total_pymnt_inv','total_rec_prncp','total_rec_int','total_rec_late_fee','recoveries','collection_recovery_fee','last_pymnt_d','last_pymnt_amnt','next_pymnt_d','last_credit_pull_d','collections_12_mths_ex_med','mths_since_last_major_derog','policy_code','application_type','annual_inc_joint','dti_joint','verification_status_joint','acc_now_delinq','tot_coll_amt','tot_cur_bal','open_acc_6m','open_il_6m','open_il_12m','open_il_24m','mths_since_rcnt_il','total_bal_il','il_util','open_rv_12m','open_rv_24m','max_bal_bc','all_util','total_rev_hi_lim','inq_fi','total_cu_tl','inq_last_12m','acc_open_past_24mths','avg_cur_bal','bc_open_to_buy','bc_util','chargeoff_within_12_mths','delinq_amnt','mo_sin_old_il_acct','mo_sin_old_rev_tl_op','mo_sin_rcnt_rev_tl_op','mo_sin_rcnt_tl','mort_acc','mths_since_recent_bc','mths_since_recent_bc_dlq','mths_since_recent_inq','mths_since_recent_revol_delinq','num_accts_ever_120_pd','num_actv_bc_tl','num_actv_rev_tl','num_bc_sats','num_bc_tl','num_il_tl','num_op_rev_tl','num_rev_accts','num_rev_tl_bal_gt_0','num_sats','num_tl_120dpd_2m','num_tl_30dpd','num_tl_90g_dpd_24m','num_tl_op_past_12m','pct_tl_nvr_dlq','percent_bc_gt_75','tax_liens','tot_hi_cred_lim','total_bal_ex_mort','total_bc_limit','total_il_high_credit_limit'

# %%
# dropping identified columns from dataframe
lending.drop(['id','member_id','funded_amnt','funded_amnt_inv','emp_title','pymnt_plan','url','desc','title','zip_code','dti','delinq_2yrs','earliest_cr_line','inq_last_6mths','mths_since_last_delinq','mths_since_last_record','open_acc','pub_rec','revol_bal','revol_util','total_acc','initial_list_status','out_prncp','out_prncp_inv','total_pymnt','total_pymnt_inv','total_rec_prncp','total_rec_int','total_rec_late_fee','recoveries','collection_recovery_fee','last_pymnt_d','last_pymnt_amnt','next_pymnt_d','last_credit_pull_d','collections_12_mths_ex_med','mths_since_last_major_derog','policy_code','application_type','annual_inc_joint','dti_joint','verification_status_joint','acc_now_delinq','tot_coll_amt','tot_cur_bal','open_acc_6m','open_il_6m','open_il_12m','open_il_24m','mths_since_rcnt_il','total_bal_il','il_util','open_rv_12m','open_rv_24m','max_bal_bc','all_util','total_rev_hi_lim','inq_fi','total_cu_tl','inq_last_12m','acc_open_past_24mths','avg_cur_bal','bc_open_to_buy','bc_util','chargeoff_within_12_mths','delinq_amnt','mo_sin_old_il_acct','mo_sin_old_rev_tl_op','mo_sin_rcnt_rev_tl_op','mo_sin_rcnt_tl','mort_acc','mths_since_recent_bc','mths_since_recent_bc_dlq','mths_since_recent_inq','mths_since_recent_revol_delinq','num_accts_ever_120_pd','num_actv_bc_tl','num_actv_rev_tl','num_bc_sats','num_bc_tl','num_il_tl','num_op_rev_tl','num_rev_accts','num_rev_tl_bal_gt_0','num_sats','num_tl_120dpd_2m','num_tl_30dpd','num_tl_90g_dpd_24m','num_tl_op_past_12m','pct_tl_nvr_dlq','percent_bc_gt_75','tax_liens','tot_hi_cred_lim','total_bal_ex_mort','total_bc_limit','total_il_high_credit_limit'],axis=1,inplace=True)

# %%
lending.describe()
# Out:
#           loan_amnt   installment    annual_inc  pub_rec_bankruptcies
# count  39717.000000  39717.000000  3.971700e+04          39020.000000
# mean   11219.443815    324.561922  6.896893e+04              0.043260
# std     7456.670694    208.874874  6.379377e+04              0.204324
# min      500.000000     15.690000  4.000000e+03              0.000000
# 25%     5500.000000    167.020000  4.040400e+04              0.000000
# 50%    10000.000000    280.220000  5.900000e+04              0.000000
# 75%    15000.000000    430.780000  8.230000e+04              0.000000
# max    35000.000000   1305.190000  6.000000e+06              2.000000

# %%
lending.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'purpose', 'addr_state',
#        'pub_rec_bankruptcies'],
#       dtype='object')

# %% [markdown]
# ## Now we have dropped un-wanted columns which is not going to help us to find the identifier for defaulter based on data sampleing
#
# ### Now we have total columns of 15

# %%
lending.shape
# Out:
# (39717, 15)

# %% [markdown]
# ### now let's looks at data types and ensure all columns have appropriate data types

# %%
lending.dtypes
# Out:
# loan_amnt                 int64
# term                     object
# int_rate                 object
# installment             float64
# grade                    object
# sub_grade                object
# emp_length               object
# home_ownership           object
# annual_inc              float64
# verification_status      object
# issue_d                  object
# loan_status              object
# purpose                  object
# addr_state               object
# pub_rec_bankruptcies    float64
# dtype: object

# %%
lending.head(10)
# Out:
#    loan_amnt        term int_rate  installment grade sub_grade emp_length  \
# 0       5000   36 months   10.65%       162.87     B        B2  10+ years
# 1       2500   60 months   15.27%        59.83     C        C4   < 1 year
# 2       2400   36 months   15.96%        84.33     C        C5  10+ years
# 3      10000   36 months   13.49%       339.31     C        C1  10+ years
# 4       3000   60 months   12.69%        67.79     B        B5     1 year
# 5       5000   36 months    7.90%       156.46     A        A4    3 years
# 6       7000   60 months   15.96%       170.08     C        C5    8 years
# 7       3000   36 months   18.64%       109.43     E        E1    9 years
# 8       5600   60 months   21.28%       152.39     F        F2    4 years
# 9       5375   60 months   12.69%       121.45     B        B5   < 1 year
#
#   home_ownership  annual_inc verification_status issue_d  loan_status  \
# 0           RENT     24000.0            Verified  Dec-11   Fully Paid
# ...

# %% [markdown]
# ### To ensure no null values in the data

# %%
lending.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_amnt             39717 non-null  int64
#  1   term                  39717 non-null  object
#  2   int_rate              39717 non-null  object
#  3   installment           39717 non-null  float64
#  4   grade                 39717 non-null  object
#  5   sub_grade             39717 non-null  object
#  6   emp_length            38642 non-null  object
#  7   home_ownership        39717 non-null  object
#  8   annual_inc            39717 non-null  float64
#  9   verification_status   39717 non-null  object
#  10  issue_d               39717 non-null  object
#  11  loan_status           39717 non-null  object
#  12  purpose               39717 non-null  object
#  13  addr_state            39717 non-null  object
#  14  pub_rec_bankruptcies  39020 non-null  float64
# ...

# %% [markdown]
# ### issue_d do not see any significant value this field can play to identify defaulter hence removing

# %%
lending.drop(['issue_d'],axis=1,inplace=True)

# %% [markdown]
# ### check the result

# %%
lending.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'loan_status', 'purpose', 'addr_state', 'pub_rec_bankruptcies'],
#       dtype='object')

# %%
lending.head(10)
# Out:
#    loan_amnt        term int_rate  installment grade sub_grade emp_length  \
# 0       5000   36 months   10.65%       162.87     B        B2  10+ years
# 1       2500   60 months   15.27%        59.83     C        C4   < 1 year
# 2       2400   36 months   15.96%        84.33     C        C5  10+ years
# 3      10000   36 months   13.49%       339.31     C        C1  10+ years
# 4       3000   60 months   12.69%        67.79     B        B5     1 year
# 5       5000   36 months    7.90%       156.46     A        A4    3 years
# 6       7000   60 months   15.96%       170.08     C        C5    8 years
# 7       3000   36 months   18.64%       109.43     E        E1    9 years
# 8       5600   60 months   21.28%       152.39     F        F2    4 years
# 9       5375   60 months   12.69%       121.45     B        B5   < 1 year
#
#   home_ownership  annual_inc verification_status  loan_status  \
# 0           RENT     24000.0            Verified   Fully Paid
# ...

# %% [markdown]
# ### Concluding no outliner record for loan amount by looking at min, mean and 25 to 75 percentil

# %%
lending.describe()
# Out:
#           loan_amnt   installment    annual_inc  pub_rec_bankruptcies
# count  39717.000000  39717.000000  3.971700e+04          39020.000000
# mean   11219.443815    324.561922  6.896893e+04              0.043260
# std     7456.670694    208.874874  6.379377e+04              0.204324
# min      500.000000     15.690000  4.000000e+03              0.000000
# 25%     5500.000000    167.020000  4.040400e+04              0.000000
# 50%    10000.000000    280.220000  5.900000e+04              0.000000
# 75%    15000.000000    430.780000  8.230000e+04              0.000000
# max    35000.000000   1305.190000  6.000000e+06              2.000000

# %% [markdown]
# ### looking at annual_inc it seems convering into integer will give better picture to understand outliners

# %%
lending['annual_inc']=lending['annual_inc'].astype('int64')

# %%
lending.dtypes
# Out:
# loan_amnt                 int64
# term                     object
# int_rate                 object
# installment             float64
# grade                    object
# sub_grade                object
# emp_length               object
# home_ownership           object
# annual_inc                int64
# verification_status      object
# loan_status              object
# purpose                  object
# addr_state               object
# pub_rec_bankruptcies    float64
# dtype: object

# %%
lending.describe()
# Out:
#           loan_amnt   installment    annual_inc  pub_rec_bankruptcies
# count  39717.000000  39717.000000  3.971700e+04          39020.000000
# mean   11219.443815    324.561922  6.896892e+04              0.043260
# std     7456.670694    208.874874  6.379377e+04              0.204324
# min      500.000000     15.690000  4.000000e+03              0.000000
# 25%     5500.000000    167.020000  4.040400e+04              0.000000
# 50%    10000.000000    280.220000  5.900000e+04              0.000000
# 75%    15000.000000    430.780000  8.230000e+04              0.000000
# max    35000.000000   1305.190000  6.000000e+06              2.000000

# %%
lending.head(10)
# Out:
#    loan_amnt        term int_rate  installment grade sub_grade emp_length  \
# 0       5000   36 months   10.65%       162.87     B        B2  10+ years
# 1       2500   60 months   15.27%        59.83     C        C4   < 1 year
# 2       2400   36 months   15.96%        84.33     C        C5  10+ years
# 3      10000   36 months   13.49%       339.31     C        C1  10+ years
# 4       3000   60 months   12.69%        67.79     B        B5     1 year
# 5       5000   36 months    7.90%       156.46     A        A4    3 years
# 6       7000   60 months   15.96%       170.08     C        C5    8 years
# 7       3000   36 months   18.64%       109.43     E        E1    9 years
# 8       5600   60 months   21.28%       152.39     F        F2    4 years
# 9       5375   60 months   12.69%       121.45     B        B5   < 1 year
#
#   home_ownership  annual_inc verification_status  loan_status  \
# 0           RENT       24000            Verified   Fully Paid
# ...

# %% [markdown]
# ### to identify outliners and we could see lot of abnormal beyond max value

# %%
df=lending[['annual_inc']]
df.boxplot()
#sns.boxplot(data = lending, y = 'annual_inc')
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(data = lending, x = 'annual_inc')
# Out:
# <AxesSubplot:xlabel='annual_inc'>

# %%
lending.describe()
# Out:
#           loan_amnt   installment    annual_inc  pub_rec_bankruptcies
# count  39717.000000  39717.000000  3.971700e+04          39020.000000
# mean   11219.443815    324.561922  6.896892e+04              0.043260
# std     7456.670694    208.874874  6.379377e+04              0.204324
# min      500.000000     15.690000  4.000000e+03              0.000000
# 25%     5500.000000    167.020000  4.040400e+04              0.000000
# 50%    10000.000000    280.220000  5.900000e+04              0.000000
# 75%    15000.000000    430.780000  8.230000e+04              0.000000
# max    35000.000000   1305.190000  6.000000e+06              2.000000

# %% [markdown]
# ### removed outliner for annual income 2 records

# %%
lending=lending[lending.annual_inc < 3000000]

# %%
lending.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39715 entries, 0 to 39716
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_amnt             39715 non-null  int64
#  1   term                  39715 non-null  object
#  2   int_rate              39715 non-null  object
#  3   installment           39715 non-null  float64
#  4   grade                 39715 non-null  object
#  5   sub_grade             39715 non-null  object
#  6   emp_length            38640 non-null  object
#  7   home_ownership        39715 non-null  object
#  8   annual_inc            39715 non-null  int64
#  9   verification_status   39715 non-null  object
#  10  loan_status           39715 non-null  object
#  11  purpose               39715 non-null  object
#  12  addr_state            39715 non-null  object
#  13  pub_rec_bankruptcies  39018 non-null  float64
# dtypes: float64(2), int64(2), object(10)
# ...

# %% [markdown]
# ### Fixing interest rate field and removing percentage symbol

# %%
lending.int_rate=lending.int_rate.apply(lambda x: x[:-1])

# %% [markdown]
# ### Validate the interest rate field value looks good

# %%
lending.head(10)
# Out:
#    loan_amnt        term int_rate  installment grade sub_grade emp_length  \
# 0       5000   36 months    10.65       162.87     B        B2  10+ years
# 1       2500   60 months    15.27        59.83     C        C4   < 1 year
# 2       2400   36 months    15.96        84.33     C        C5  10+ years
# 3      10000   36 months    13.49       339.31     C        C1  10+ years
# 4       3000   60 months    12.69        67.79     B        B5     1 year
# 5       5000   36 months     7.90       156.46     A        A4    3 years
# 6       7000   60 months    15.96       170.08     C        C5    8 years
# 7       3000   36 months    18.64       109.43     E        E1    9 years
# 8       5600   60 months    21.28       152.39     F        F2    4 years
# 9       5375   60 months    12.69       121.45     B        B5   < 1 year
#
#   home_ownership  annual_inc verification_status  loan_status  \
# 0           RENT       24000            Verified   Fully Paid
# ...

# %% [markdown]
# ### convert interest rate data type to float

# %%
lending['int_rate']=lending['int_rate'].astype('float64')

# %%
sns.violinplot(data = lending, x = 'int_rate')
# Out:
# <AxesSubplot:xlabel='int_rate'>

# %%
lending.dtypes
# Out:
# loan_amnt                 int64
# term                     object
# int_rate                float64
# installment             float64
# grade                    object
# sub_grade                object
# emp_length               object
# home_ownership           object
# annual_inc                int64
# verification_status      object
# loan_status              object
# purpose                  object
# addr_state               object
# pub_rec_bankruptcies    float64
# dtype: object

# %%
lending.emp_length.value_counts()
# Out:
# 10+ years    8878
# < 1 year     4583
# 2 years      4388
# 3 years      4094
# 4 years      3436
# 5 years      3282
# 1 year       3240
# 6 years      2229
# 7 years      1773
# 8 years      1479
# 9 years      1258
# Name: emp_length, dtype: int64

# %%
lending.int_rate.describe()
# Out:
# count    39715.000000
# mean        12.021194
# std          3.724911
# min          5.420000
# 25%          9.250000
# 50%         11.860000
# 75%         14.590000
# max         24.590000
# Name: int_rate, dtype: float64

# %%
lending.int_rate.value_counts().sort_values(ascending=False)
# Out:
# 10.99    956
# 13.49    826
# 11.49    825
# 7.51     787
# 7.88     725
#         ...
# 21.48      1
# 24.40      1
# 24.59      1
# 22.64      1
# 17.44      1
# Name: int_rate, Length: 371, dtype: int64

# %%
lending.int_rate.describe()
# Out:
# count    39715.000000
# mean        12.021194
# std          3.724911
# min          5.420000
# 25%          9.250000
# 50%         11.860000
# 75%         14.590000
# max         24.590000
# Name: int_rate, dtype: float64

# %%
lending.loan_amnt.describe()
# Out:
# count    39715.000000
# mean     11219.253431
# std       7456.472500
# min        500.000000
# 25%       5500.000000
# 50%      10000.000000
# 75%      15000.000000
# max      35000.000000
# Name: loan_amnt, dtype: float64

# %%
lending.annual_inc.describe()
# Out:
# count    3.971500e+04
# mean     6.872312e+04
# std      5.305154e+04
# min      4.000000e+03
# 25%      4.040200e+04
# 50%      5.900000e+04
# 75%      8.229800e+04
# max      2.039784e+06
# Name: annual_inc, dtype: float64

# %% [markdown]
# ### there is still huge difference in max value vs 25 to 75% and mean, std values of annual income and we need to eliminate few more outliners for better analysis

# %%
lending.annual_inc.plot.box()
plt.show()

# %%
sns.violinplot(data = lending, x = 'annual_inc')
# Out:
# <AxesSubplot:xlabel='annual_inc'>

# %%
lending.annual_inc.value_counts().plot.bar()
plt.show()

# %%
lending=lending[lending.annual_inc < 200000]

# %% [markdown]
# ### Validate the min/max and mean, std values and now it looks better

# %%
lending.annual_inc.describe()
# Out:
# count     39009.000000
# mean      64376.574303
# std       32892.642093
# min        4000.000000
# 25%       40000.000000
# 50%       58000.000000
# 75%       80000.000000
# max      199992.000000
# Name: annual_inc, dtype: float64

# %% [markdown]
# ### Now plot box also looks better

# %%
lending.annual_inc.plot.box()
plt.show()

# %% [markdown]
# ### Forgot to remove load status 'Current' since those applicants are new and not completed yet which is not required for our analysis

# %%
df=lending[lending.loan_status != 'Current']

# %% [markdown]
# ### We have completed removing outliner for all critical columns, now we will start work on creating binning for loan amount, interest rate, annual income and employment lenngth for apply EDA process and creating new columns

# %%
def ln_amt(x):
    if x <= 5500:
        return "Small"
    elif 5500 < x <= 10000:
        return "Medium"
    elif 10000 < x <= 15000:
        return "Large"
    else:
        return "Very Large"
    
#lending.loan_amnt.apply(ln_amt).value_counts()
lending['loan_type']=lending.loan_amnt.apply(ln_amt)

# %%
lending.loan_type.value_counts()
# Out:
# Medium        12287
# Small         10077
# Very Large     8779
# Large          7866
# Name: loan_type, dtype: int64

# %% [markdown]
# ### To simplify bucketting converting float into integer for interest rate which will make easy

# %%
lending['int_rate']=lending['int_rate'].astype('int64')

# %%
lending.head(10)
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade emp_length  \
# 0       5000   36 months        10       162.87     B        B2  10+ years
# 1       2500   60 months        15        59.83     C        C4   < 1 year
# 2       2400   36 months        15        84.33     C        C5  10+ years
# 3      10000   36 months        13       339.31     C        C1  10+ years
# 4       3000   60 months        12        67.79     B        B5     1 year
# 5       5000   36 months         7       156.46     A        A4    3 years
# 6       7000   60 months        15       170.08     C        C5    8 years
# 7       3000   36 months        18       109.43     E        E1    9 years
# 8       5600   60 months        21       152.39     F        F2    4 years
# 9       5375   60 months        12       121.45     B        B5   < 1 year
#
#   home_ownership  annual_inc verification_status  loan_status  \
# 0           RENT       24000            Verified   Fully Paid
# ...

# %% [markdown]
# ### We will do binning for interest rate

# %%
def interest(x):
    if x <= 10:
        return "Low"
    elif 10 < x <= 12:
        return "Medium"
    elif 12 < x <= 15:
        return "High"
    else:
        return "Very High"
#lending.int_rate.apply(interest).value_counts()
lending['int_range']=lending.int_rate.apply(interest)

# %%
lending.dtypes
# Out:
# loan_amnt                 int64
# term                     object
# int_rate                  int64
# installment             float64
# grade                    object
# sub_grade                object
# emp_length               object
# home_ownership           object
# annual_inc                int64
# verification_status      object
# loan_status              object
# purpose                  object
# addr_state               object
# pub_rec_bankruptcies    float64
# loan_type                object
# int_range                object
# dtype: object

# %% [markdown]
# ### Let's do binning for annual income

# %%
def aincome(x):
    if x <= 40000:
        return "Low"
    elif 40000 < x <= 60000:
        return "Medium"
    elif 60000 < x <= 90000:
        return "High"
    else:
        return "Very High"
lending['income_range']=lending.annual_inc.apply(aincome)

# %%
lending.income_range.value_counts()
# Out:
# Medium       11608
# High         10477
# Low           9877
# Very High     7047
# Name: income_range, dtype: int64

# %%
lending.head(10)
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade emp_length  \
# 0       5000   36 months        10       162.87     B        B2  10+ years
# 1       2500   60 months        15        59.83     C        C4   < 1 year
# 2       2400   36 months        15        84.33     C        C5  10+ years
# 3      10000   36 months        13       339.31     C        C1  10+ years
# 4       3000   60 months        12        67.79     B        B5     1 year
# 5       5000   36 months         7       156.46     A        A4    3 years
# 6       7000   60 months        15       170.08     C        C5    8 years
# 7       3000   36 months        18       109.43     E        E1    9 years
# 8       5600   60 months        21       152.39     F        F2    4 years
# 9       5375   60 months        12       121.45     B        B5   < 1 year
#
#   home_ownership  annual_inc verification_status  loan_status  \
# 0           RENT       24000            Verified   Fully Paid
# ...

# %% [markdown]
# ### Noticed load status Current still not cleaned-up properly hence doing it again

# %%
lending=lending[lending.loan_status != 'Current']

# %%
lending.head(10)
# Out:
#     loan_amnt        term  int_rate  installment grade sub_grade emp_length  \
# 0        5000   36 months        10       162.87     B        B2  10+ years
# 1        2500   60 months        15        59.83     C        C4   < 1 year
# 2        2400   36 months        15        84.33     C        C5  10+ years
# 3       10000   36 months        13       339.31     C        C1  10+ years
# 5        5000   36 months         7       156.46     A        A4    3 years
# 6        7000   60 months        15       170.08     C        C5    8 years
# 7        3000   36 months        18       109.43     E        E1    9 years
# 8        5600   60 months        21       152.39     F        F2    4 years
# 9        5375   60 months        12       121.45     B        B5   < 1 year
# 10       6500   60 months        14       153.45     C        C3    5 years
#
#    home_ownership  annual_inc verification_status  loan_status  \
# 0            RENT       24000            Verified   Fully Paid
# ...

# %% [markdown]
# ### Lets create binning for installment amount to understand behavior of people when installement amt is less or high

# %%
lending['installment']=lending['installment'].astype('int64')

# %%
lending.installment.describe()
# Out:
# count    37888.000000
# mean       317.683752
# std        204.421097
# min         15.000000
# 25%        164.000000
# 50%        275.000000
# 75%        418.000000
# max       1305.000000
# Name: installment, dtype: float64

# %%
lending.installment.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### We could see in the plat box there is outliner beyoing max number and we should clean-up those outliners

# %%
lending=lending[lending.installment < 900]

# %%
lending.installment.plot.box()
# Out:
# <AxesSubplot:>

# %%
lending.installment.describe()
# Out:
# count    37451.000000
# mean       309.437345
# std        190.356148
# min         15.000000
# 25%        163.000000
# 50%        272.000000
# 75%        410.000000
# max        899.000000
# Name: installment, dtype: float64

# %% [markdown]
# ### Let's do binning for Installement Amount

# %%
def instlmnt(x):
    if x <= 163:
        return "Low_AMT"
    elif 163 < x <= 272:
        return "Medium_AMT"
    elif 272 < x <= 410:
        return "High_AMT"
    else:
        return "Very High_AMT"
lending['installment_range']=lending.installment.apply(instlmnt)

# %%
lending.installment_range.value_counts()
# Out:
# Medium_AMT       9411
# Low_AMT          9379
# High_AMT         9341
# Very High_AMT    9320
# Name: installment_range, dtype: int64

# %%
lending.groupby(['income_range','loan_status'])['loan_status'].count()
# Out:
# income_range  loan_status
# High          Charged Off    1289
#               Fully Paid     8691
# Low           Charged Off    1751
#               Fully Paid     7947
# Medium        Charged Off    1723
#               Fully Paid     9526
# Very High     Charged Off     703
#               Fully Paid     5821
# Name: loan_status, dtype: int64

# %%
lending.annual_inc.describe()
# Out:
# count     37451.000000
# mean      63653.818937
# std       32472.029766
# min        4000.000000
# 25%       40000.000000
# 50%       57000.000000
# 75%       80000.000000
# max      199992.000000
# Name: annual_inc, dtype: float64

# %%
lending[(lending.annual_inc > 60000) & (lending.annual_inc <= 90000)]
# Out:
#        loan_amnt        term  int_rate  installment grade sub_grade  \
# 10          6500   60 months        14          153     C        C3
# 11         12000   36 months        12          402     B        B5
# 18          6000   36 months        11          198     B        B3
# 19          9200   36 months         6          280     A        A1
# 24          6000   36 months        11          198     B        B3
# ...          ...         ...       ...          ...   ...       ...
# 39698       5000   36 months         9          159     B        B2
# 39701       5300   36 months         8          167     A        A5
# 39709       5000   36 months        11          164     C        C4
# 39710       5000   36 months         7          155     A        A2
# 39711       5000   36 months         8          158     B        B1
#
#       emp_length home_ownership  annual_inc verification_status  loan_status  \
# ...

# %%
lending.emp_length.value_counts()
# Out:
# 10+ years    8108
# < 1 year     4416
# 2 years      4176
# 3 years      3924
# 4 years      3246
# 5 years      3107
# 1 year       3103
# 6 years      2113
# 7 years      1663
# 8 years      1380
# 9 years      1200
# Name: emp_length, dtype: int64

# %% [markdown]
# ### removing string value from employment history data

# %%
lending['emp_length']=lending['emp_length'].str.replace('years','')

# %%
lending['emp_length']=lending['emp_length'].str.replace('','')

# %%
lending['emp_length']=lending['emp_length'].str.replace('year','')

# %%
lending['emp_length']=lending['emp_length'].str.replace('+','')
# Out:
# C:\Users\NARESH~1\AppData\Local\Temp\1/ipykernel_5492/737840524.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   lending['emp_length']=lending['emp_length'].str.replace('+','')

# %%
lending['emp_length']=lending['emp_length'].str.replace(' ','')

# %%
lending['emp_length']=lending['emp_length'].str.replace('<','')

# %% [markdown]
# ## Now convert that into integer so we can do bucketting for experience field and start our data analysis and recommendation

# %% [markdown]
# ### lending['emp_length']=lending['emp_length'].astype('int64')
# ### Unable to convert since columen has some string value n/a which we need to remove in similar fashion

# %%
lending['emp_length']=lending['emp_length'].str.replace(' ','0')

# %%
lending.dtypes
# Out:
# loan_amnt                 int64
# term                     object
# int_rate                  int64
# installment               int64
# grade                    object
# sub_grade                object
# emp_length               object
# home_ownership           object
# annual_inc                int64
# verification_status      object
# loan_status              object
# purpose                  object
# addr_state               object
# pub_rec_bankruptcies    float64
# loan_type                object
# int_range                object
# income_range             object
# installment_range        object
# dtype: object

# %%
lending.emp_length.describe()
# Out:
# count     36436
# unique       10
# top          10
# freq       8108
# Name: emp_length, dtype: object

# %%
lending.head(10)
# Out:
#     loan_amnt        term  int_rate  installment grade sub_grade emp_length  \
# 0        5000   36 months        10          162     B        B2         10
# 1        2500   60 months        15           59     C        C4          1
# 2        2400   36 months        15           84     C        C5         10
# 3       10000   36 months        13          339     C        C1         10
# 5        5000   36 months         7          156     A        A4          3
# 6        7000   60 months        15          170     C        C5          8
# 7        3000   36 months        18          109     E        E1          9
# 8        5600   60 months        21          152     F        F2          4
# 9        5375   60 months        12          121     B        B5          1
# 10       6500   60 months        14          153     C        C3          5
#
#    home_ownership  annual_inc verification_status  loan_status  \
# 0            RENT       24000            Verified   Fully Paid
# ...

# %% [markdown]
# ### Starting the EDA Analysis for Univariate
# ### Rank Log Scale

# %%
lending.groupby('term')['loan_status'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='term'>

# %% [markdown]
# ### In this one we could see 36 month term loan volumes are high compare to longer loan term 60 month
# ### This also gives us indication most data population is at short term loan
# ### Now we need to figure out success rate between short and long term loan

# %%
lending.groupby(['term','loan_status'])['loan_status'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='term,loan_status'>

# %% [markdown]
# ### We could see clearly the short term load are closed with high number compare to long term loans
# ### let's compare these data with other ordered columns like loan amount, interest rate, installment amount, annual salary range

# %%
lending.corr()
# Out:
#                       loan_amnt  int_rate  installment  annual_inc  \
# loan_amnt              1.000000  0.280077     0.926135    0.394994
# int_rate               0.280077  1.000000     0.258184    0.048381
# installment            0.926135  0.258184     1.000000    0.391364
# annual_inc             0.394994  0.048381     0.391364    1.000000
# pub_rec_bankruptcies  -0.031040  0.085297    -0.028156   -0.014542
#
#                       pub_rec_bankruptcies
# loan_amnt                        -0.031040
# int_rate                          0.085297
# installment                      -0.028156
# annual_inc                       -0.014542
# pub_rec_bankruptcies              1.000000

# %%
lending.groupby(['loan_type','loan_status'])['loan_status'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='loan_type,loan_status'>

# %% [markdown]
# ### We see the medium and large loan amount are charged off let's understand further who are they

# %%
lending.groupby(['loan_status','income_range'])['loan_status'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='loan_status,income_range'>

# %% [markdown]
# ### We see that income type LOW and Medium people charged off loan more

# %%
lending.groupby(['loan_status','installment_range'])['loan_status'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='loan_status,installment_range'>

# %% [markdown]
# ### We could see if the installment amount is very high > 410$ then high chances of default

# %%
lending.groupby(['loan_status','int_range'])['loan_status'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='loan_status,int_range'>

# %% [markdown]
# ### We could see interest rate high or very high those loans not closed

# %%
# Let's understand the load type how its doing on closing the loan
lending.groupby(['loan_status','purpose'])['loan_status'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='loan_status,purpose'>

# %% [markdown]
# ### We could see the Debt consolitation type of loan not closed

# %%
lending.groupby(['loan_status','purpose'])['loan_status'].count()
# Out:
# loan_status  purpose
# Charged Off  car                     160
#              credit_card             527
#              debt_consolidation     2691
#              educational              54
#              home_improvement        334
#              house                    54
#              major_purchase          219
#              medical                 106
#              moving                   90
#              other                   611
#              renewable_energy         18
#              small_business          455
#              vacation                 53
#              wedding                  94
# Fully Paid   car                    1323
#              credit_card            4361
#              debt_consolidation    14852
#              educational             267
#              home_improvement       2382
#              house                   291
#              major_purchase         1884
#              medical                 556
# ...

# %%
lending.corr()
# Out:
#                       loan_amnt  int_rate  installment  annual_inc  \
# loan_amnt              1.000000  0.280077     0.926135    0.394994
# int_rate               0.280077  1.000000     0.258184    0.048381
# installment            0.926135  0.258184     1.000000    0.391364
# annual_inc             0.394994  0.048381     0.391364    1.000000
# pub_rec_bankruptcies  -0.031040  0.085297    -0.028156   -0.014542
#
#                       pub_rec_bankruptcies
# loan_amnt                        -0.031040
# int_rate                          0.085297
# installment                      -0.028156
# annual_inc                       -0.014542
# pub_rec_bankruptcies              1.000000

# %%
lending.groupby(['loan_status','pub_rec_bankruptcies'])['loan_status'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='loan_status,pub_rec_bankruptcies'>

# %% [markdown]
# ### We are not seeing any big impact on bankcruptcies history since we could see high charge off on people who never had bankruptcies

# %%
import seaborn as sns

# %%
lending.groupby(['loan_status','addr_state'])['loan_status'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='loan_status,addr_state'>

# %% [markdown]
# ### We could see that Californian not paid 20% of the loans; let's identify which type of loan and other indictors

# %%
lending.groupby(['loan_status','loan_type',(lending.addr_state=='CA')])['loan_status'].count().plot.bar()
# Out:
# <AxesSubplot:xlabel='loan_status,loan_type,addr_state'>

# %%
lending.groupby(['loan_status','addr_state'])['loan_status'].count().plot.pie()
# Out:
# <AxesSubplot:ylabel='loan_status'>

# %%
sns.pairplot(lending[['loan_amnt','annual_inc','installment','loan_status']])
plt.show()

# %% [markdown]
# * Final Conclustion & Recommendation
# * if loan type is debt consolidation or Small Business
# * If the loan amount is > 15000
# * if Loan term is longer
# * If the annual income is < 60000 (Low and Medium)
# * if monthly installment amount is greater than 410
# * if interest rate is greater than 15%
# * if applicant is having rental and Mortgae
# * if applicant state is California, New York, Floria, New Jersey
# * if employment length between 1 to 3 years or > 10 year
# * These are indicators for defaulters

# %%
sns.countplot(data = lending, x = 'home_ownership', hue = 'loan_status')
# Out:
# <AxesSubplot:xlabel='home_ownership', ylabel='count'>

# %%
sns.barplot(data = lending, x='annual_inc', y = 'loan_status')
# Out:
# <AxesSubplot:xlabel='annual_inc', ylabel='loan_status'>

# %%
sns.countplot(data = lending, y = 'purpose', hue = 'loan_status')
# Out:
# <AxesSubplot:xlabel='count', ylabel='purpose'>

# %%
fig,ax=plt.subplots(figsize=(18,12))
ax.set(xscale='log')
sns.countplot(data = lending[lending.loan_status=='Charged Off'], y = 'addr_state', hue = 'loan_status')
# Out:
# <AxesSubplot:xlabel='count', ylabel='addr_state'>

# %%
sns.countplot(data = lending, y = 'loan_type', hue = 'loan_status')
# Out:
# <AxesSubplot:xlabel='count', ylabel='loan_type'>

# %% [markdown]
# > Loans of medium level have higher percetnages in charged off as well as fully paid

# %%
fig,ax=plt.subplots(figsize=(12,8))
ax.set(xscale='log')
sns.countplot(data = lending, y = 'int_rate', hue = 'loan_status')
# Out:
# <AxesSubplot:xlabel='count', ylabel='int_rate'>

# %%
fig,ax=plt.subplots(figsize=(12,8))
ax.set(xscale='log')
sns.countplot(data = lending, y = 'int_range', hue = 'loan_status')
# Out:
# <AxesSubplot:xlabel='count', ylabel='int_range'>

# %%
fig,ax=plt.subplots(figsize=(12,8))
ax.set(xscale='log')
sns.countplot(data = lending, y = 'income_range', hue = 'loan_status')
# Out:
# <AxesSubplot:xlabel='count', ylabel='income_range'>

# %%
fig,ax=plt.subplots(figsize=(12,8))
ax.set(xscale='log')
sns.countplot(data = lending, y = 'installment_range', hue = 'loan_status')
# Out:
# <AxesSubplot:xlabel='count', ylabel='installment_range'>

# %%
fig,ax=plt.subplots(figsize=(12,8))
ax.set(xscale='log')
sns.countplot(data = lending, y = 'emp_length', hue = 'loan_status')
# Out:
# <AxesSubplot:xlabel='count', ylabel='emp_length'>

# %% [markdown]
# ### Understand the spread of our consumer variables from the dataset based on our learnings above analysis.

# %%
sns.violinplot(x='emp_length', y ='loan_amnt', data =lending, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='emp_length', ylabel='loan_amnt'>

# %%
sns.boxplot(x='emp_length', y ='loan_amnt', data =lending, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='emp_length', ylabel='loan_amnt'>

# %% [markdown]
# > Employess with 10 or greater years of exp tend to apply for more loan amount

# %%
sns.violinplot(y='int_rate', x='term', data =lending, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='term', ylabel='int_rate'>

# %%
sns.boxplot(y='int_rate', x='term', data =lending, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='term', ylabel='int_rate'>

# %% [markdown]
# > Its evident that the interest rate are higher if the duration is longer

# %%
sns.violinplot(y='purpose', x='loan_amnt', data =lending, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='loan_amnt', ylabel='purpose'>

# %%
sns.boxplot(y='purpose', x='loan_amnt', data =lending, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='loan_amnt', ylabel='purpose'>

# %% [markdown]
# > The median of debt consolidation is comparitively higher than rest of the purposes
